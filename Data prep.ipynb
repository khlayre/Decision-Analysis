# %%
import pandas as pd
import numpy as np
import scipy as sp
import math
import matplotlib.pyplot as plt
from matplotlib import colors
import seaborn as sns

# %%
data = pd.read_csv(r'/Users/angelaokorie/Documents/DISSERTATION/python/solution_final.csv')
df = pd.DataFrame(data)
df.drop(df.iloc[:, 0:18], inplace = True, axis = 1)
df.to_csv('/Users/angelaokorie/Documents/DISSERTATION/python/preprocessed.csv', index=False)
data2 = pd.read_csv(r'/Users/angelaokorie/Documents/DISSERTATION/python/preprocessed1.csv')
data3 = pd.read_csv(r'/Users/angelaokorie/Documents/DISSERTATION/python/data3.csv')
data2.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-47836b5402f4> in <module>
# ----> 1 data = pd.read_csv(r'/Users/angelaokorie/Documents/DISSERTATION/python/solution_final.csv')
#       2 df = pd.DataFrame(data)
#       3 df.drop(df.iloc[:, 0:18], inplace = True, axis = 1)
#       4 df.to_csv('/Users/angelaokorie/Documents/DISSERTATION/python/preprocessed.csv', index=False)
#       5 data2 = pd.read_csv(r'/Users/angelaokorie/Documents/DISSERTATION/python/preprocessed1.csv')
#
# NameError: name 'pd' is not defined

# %%
data2.describe()
# Out:
#                Q1         Q1a          Q2         Q2a          Q3         Q3a  \
# count  213.000000  213.000000  213.000000  213.000000  213.000000  213.000000
# mean     1.971831    7.323944    1.938967    7.370892    2.140845    7.657277
# std      0.895036    1.457977    0.813235    1.327680    0.686029    1.328180
# min      1.000000    2.000000    1.000000    3.000000    1.000000    3.000000
# 25%      1.000000    6.000000    1.000000    7.000000    2.000000    7.000000
# 50%      2.000000    8.000000    2.000000    7.000000    2.000000    8.000000
# 75%      3.000000    9.000000    3.000000    9.000000    3.000000    9.000000
# max      3.000000    9.000000    3.000000    9.000000    3.000000    9.000000
#
#                Q4         Q4a          Q5         Q5a  ...         Q8a  \
# count  213.000000  213.000000  213.000000  213.000000  ...  213.000000
# mean     1.967136    7.276995    2.042254    7.539906  ...    3.413146
# ...

# %%
# Visualizing the Distribution of CI.

x = data2['CR_1']
n_bins = 40
legend = ['distribution']

#creating the histogram
fig, axs = plt.subplots(1,1,figsize=(10,7), tight_layout=True)

#Removing the splines in the axes
for s in ['top', 'bottom', 'left', 'right']: 
    axs.spines[s].set_visible(False)
    

#remove x,y ticks    
axs.xaxis.set_ticks_position('none')
axs.yaxis.set_ticks_position('none')

# axs.xaxis.set_ticks_params(pad = 5)
# axs.yaxis.set_ticks_params(pad = 9)

axs.grid(b=True, color='grey', linestyle='-.', linewidth=0.5, alpha=0.6)
N, bins, patches = axs.hist(x, bins=n_bins)

#setting color scheme
fracs = ((N**(1/5))/N.max())
norm = colors.Normalize(fracs.min(), fracs.max())

for thisfrac, thispatch in zip(fracs, patches):
    color = plt.cm.viridis(norm(thisfrac))
    thispatch.set_facecolor(color)
    
plt.xlabel("CI")
plt.legend(legend)
plt.title("CI Distribution")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6d6369bcde29> in <module>
#       1 # Visualizing the Distribution of CI.
#       2
# ----> 3 x = data2['CR_1']
#       4 n_bins = 40
#       5 legend = ['distribution']
#
# NameError: name 'data2' is not defined

# %%
# Visualizing the Distribution of Congruence.
x = data2['Congruence_1']
n_bins = 40
legend = ['distribution']

#creating the histogram
fig, axs = plt.subplots(1,1,figsize=(10,7), tight_layout=True)

#Removing the splines in the axes
for s in ['top', 'bottom', 'left', 'right']: 
    axs.spines[s].set_visible(False)
    

#remove x,y ticks    
axs.xaxis.set_ticks_position('none')
axs.yaxis.set_ticks_position('none')

# axs.xaxis.set_ticks_params(pad = 5)
# axs.yaxis.set_ticks_params(pad = 9)

axs.grid(b=True, color='grey', linestyle='-.', linewidth=0.5, alpha=0.6)
N, bins, patches = axs.hist(x, bins=n_bins)

#setting color scheme
#fracs = ((N**(1/5))/N.max())
#norm = colors.Normalize(fracs.min(), fracs.max())

#for thisfrac, thispatch in zip(fracs, patches):
#    color = plt.cm.viridis(norm(thisfrac))
#    thispatch.set_facecolor(color)
    
plt.xlabel("Congruence")
plt.legend(legend)
plt.title("Congruence Distribution")

plt.show()

# %%
# Visualizing the Distribution of Dissonance.
x = data2['Dissonance_1']
n_bins = 40
legend = ['distribution']

#creating the histogram
fig, axs = plt.subplots(1,1,figsize=(10,7), tight_layout=True)

#Removing the splines in the axes
for s in ['top', 'bottom', 'left', 'right']: 
    axs.spines[s].set_visible(False)
    

#remove x,y ticks    
axs.xaxis.set_ticks_position('none')
axs.yaxis.set_ticks_position('none')

# axs.xaxis.set_ticks_params(pad = 5)
# axs.yaxis.set_ticks_params(pad = 9)

axs.grid(b=True, color='grey', linestyle='-.', linewidth=0.5, alpha=0.6)
N, bins, patches = axs.hist(x, bins=n_bins)

#setting color scheme
#fracs = ((N**(1/5))/N.max())
#norm = colors.Normalize(fracs.min(), fracs.max())

#for thisfrac, thispatch in zip(fracs, patches):
#    color = plt.cm.viridis(norm(thisfrac))
#    thispatch.set_facecolor(color)
    
plt.xlabel("Dissonance")
plt.legend(legend)
plt.title("Dissonance Distribution")

plt.show()

# %%
# Visualizing the Distribution of Koczkodaj.
x = data2['Koczkodaj_1']
n_bins = 40
legend = ['distribution']

#creating the histogram
fig, axs = plt.subplots(1,1,figsize=(10,7), tight_layout=True)

#Removing the splines in the axes
for s in ['top', 'bottom', 'left', 'right']: 
    axs.spines[s].set_visible(False)
    

#remove x,y ticks    
axs.xaxis.set_ticks_position('none')
axs.yaxis.set_ticks_position('none')

# axs.xaxis.set_ticks_params(pad = 5)
# axs.yaxis.set_ticks_params(pad = 9)

axs.grid(b=True, color='grey', linestyle='-.', linewidth=0.5, alpha=0.6)
N, bins, patches = axs.hist(x, bins=n_bins)

#setting color scheme
#fracs = ((N**(1/5))/N.max())
#norm = colors.Normalize(fracs.min(), fracs.max())

#for thisfrac, thispatch in zip(fracs, patches):
#    color = plt.cm.viridis(norm(thisfrac))
#    thispatch.set_facecolor(color)
    
plt.xlabel("Koczkodaj")
plt.legend(legend)
plt.title("Koczkodaj Distribution")

plt.show()

# %%
# Visualizing the Distribution of Age
x = data2['Q26']
plt.hist(x)
plt.show()

# %%
# Visualizing the Distribution of sex
x = data2['Q25']
plt.hist(x)
plt.show()
